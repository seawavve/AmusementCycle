# %% [markdown]
# <a href="https://colab.research.google.com/github/seawavve/AmusementCycle/blob/main/autoencoder_imageSimilarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ankonzoid/artificio
# Out:
# Cloning into 'artificio'...
# remote: Enumerating objects: 100, done.
# remote: Total 100 (delta 0), reused 0 (delta 0), pack-reused 100
# Receiving objects: 100% (100/100), 2.95 MiB | 29.92 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %ls
# %cd artificio/image_retrieval/
! python image_retrieval.py
# Out:
# artificio/  sample_data/
# /content/artificio/image_retrieval
# Reading train images from '/content/artificio/image_retrieval/data/train'...
# Reading test images from '/content/artificio/image_retrieval/data/test'...
# Image shape = (100, 100, 3)
# 2021-10-24 19:57:23.592465: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-24 19:57:23.592529: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (81868b6aedb6): /proc/driver/nvidia/version does not exist
#
# autoencoder.summary():
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      448
# ...
