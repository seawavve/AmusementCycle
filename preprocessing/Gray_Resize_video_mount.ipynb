# %% [markdown]
# <a href="https://colab.research.google.com/github/seawavve/AmusementCycle/blob/main/preprocessing/Gray_Resize_video_mount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imutils # 파이썬 OpenCV가 제공하는 기능 중 복잡하고 사용성이 떨어지는 부분을 보완(이미지 또는 비디오 스트림 파일 처리 등)
import cv2 # opencv 모듈

# %% [markdown]
# # gray_resize_vid

# %%
def gray_resize_vid(video_path):
  print("[video 시작]")
  vs = cv2.VideoCapture(video_path)

  # 비디오 저장 변수
  writer = None

  # 비디오 스트림 프레임 반복
  while True:
    # 프레임 읽기
    ret, frame = vs.read()

    # 읽은 프레임이 없는 경우 종료
    if frame is None:
        break
    
    # 프레임 resize
    frame = imutils.resize(frame, width=500)
    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
                                    
    # 저장할 비디오 설정
    if writer is None:
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter(result_path, fourcc, 25, (frame.shape[1], frame.shape[0]),False)
    #####RGB==True, non==False설정 주의


    # 비디오 저장
    if writer is not None:
        writer.write(frame)

  # 종료
  vs.release()
  cv2.destroyAllWindows()

# %%
video_path= "/content/drive/MyDrive/amusementCycle/gyro_swing1.mp4"
result_path = "/content/drive/MyDrive/amusementCycle/gyro_swing1_gray_resize.avi"

gray_resize_vid(video_path)
# Out:
# [video 시작]
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# ...
